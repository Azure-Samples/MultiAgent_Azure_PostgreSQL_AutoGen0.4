# %%
from pg_utils import init_pool
from multi_agent_chats import GroupChat
import os
# ensure to update .env file with your own values
from dotenv import load_dotenv
load_dotenv(override=True)
pw = os.getenv('POSTGRES_PASSWORD')

# %%
# [OPTIONAL]: uncomment below to run the script setting up the example postgres tables used for this demo
# !python db_init.py

# %% [markdown]
# ## Initialize a connection pool and group chat object

# %%
# Create the connection pool
connection_pool = init_pool(pw)

# %%
groupchat = GroupChat(connection_pool)
# Out:
# Agents and required resources initialized successfully

# %% [markdown]
# ## Chat with your data: Ask question!

# %% [markdown]
# #### example 1

# %%
q = "can you give me a list of all customer names?"
await groupchat.init_roundrobin(q)
# Out:
# -- 1:user -- : can you give me a list of all customer names?
#
# -- 2:schema_agent -- : I'm here to assist with database schema information and creating stored procedures. Would you like to proceed with something related to those?
#
# -- 3:shipment_agent -- : [FunctionCall(id='call_hAEPV9NZm4XnKQR8a5gLkuUA', arguments='{"query":"SELECT name FROM customer"}', name='execute_query')]
#
# -- 4:shipment_agent -- : [FunctionExecutionResult(content='[UndefinedTable(\'relation "customer" does not exist\\nLINE 1: SELECT name FROM customer\\n                         ^\\n\')]', name='execute_query', call_id='call_hAEPV9NZm4XnKQR8a5gLkuUA', is_error=False)]
#
# -- 5:shipment_agent -- : [UndefinedTable('relation "customer" does not exist\nLINE 1: SELECT name FROM customer\n                         ^\n')]
#
# -- 6:customer_agent -- : It seems there was an error related to table naming. Could you provide the correct table schema for customer details, specifically the table name and the field used to store customer names?
#
# -- 7:user_proxy -- :
# (type 'bye' to exit): try again
# -- 8:user_proxy -- : try again
# Getting schema
#
# -- 9:schema_agent -- : [FunctionCall(id='call_4MzJqPyEbDT10VvUA6GZZ6k1', arguments='{}', name='get_schema_info')]
#
# -- 10:schema_agent -- : [FunctionExecutionResult(content='[\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "customer_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "customers_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "email",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "phone",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "address",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "location_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "locations_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "city",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "state",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "country",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "zip_code",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "product_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "products_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "description",\n    "data_type": "text",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "price",\n    "data_type": "nume ...
#
# -- 11:schema_agent -- : [
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "customers_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "email",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "phone",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "address",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "locations_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "city",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "state",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "country",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "zip_code",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "products_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "description",
#     "data_type": "text",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "price",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "item_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_items_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_product_id_fkey",
#     "referenced_table": "products",
#     "referenced_column": "product_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "quantity",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "tracking_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_tracking_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_location_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "timestamp",
#     "data_type": "timestamp without time zone",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipments_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_date",
#     "data_type": "date",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "origin_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_origin_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "destination_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_destination_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_customer_id_fkey",
#     "referenced_table": "customers",
#     "referenced_column": "customer_id"
#   }
# ]
#
# -- 12:shipment_agent -- : [FunctionCall(id='call_hAEPV9NZm4XnKQR8a5gLkuUA', arguments='{"query":"SELECT name FROM customers"}', name='execute_query')]
#
# -- 13:shipment_agent -- : [FunctionExecutionResult(content="[('Alice Johnson',), ('Bob Smith',), ('Cathy Lee',), ('Marc',), ('Mehrsa',), ('Carley',), ('Adam',), ('Lili',), ('John Smith',), ('Sara Porter',), ('Sara Smith',), ('Judy Brown',)]", name='execute_query', call_id='call_hAEPV9NZm4XnKQR8a5gLkuUA', is_error=False)]
#
# -- 14:shipment_agent -- : [('Alice Johnson',), ('Bob Smith',), ('Cathy Lee',), ('Marc',), ('Mehrsa',), ('Carley',), ('Adam',), ('Lili',), ('John Smith',), ('Sara Porter',), ('Sara Smith',), ('Judy Brown',)]
#
# -- 15:customer_agent -- : Here is the list of all customer names from the database:
#
# 1. Alice Johnson
# 2. Bob Smith
# 3. Cathy Lee
# 4. Marc
# 5. Mehrsa
# 6. Carley
# 7. Adam
# 8. Lili
# 9. John Smith
# 10. Sara Porter
# 11. Sara Smith
# 12. Judy Brown
#
# Is there anything else you would like to know or any other operation you would like to perform?
#
# -- 16:user_proxy -- :
# (type 'bye' to exit): bye
# -- 17:user_proxy -- : bye
# Total messages exchanged: 17
# Conversation ended.

# %% [markdown]
# #### example 2

# %%
q = "Is there any shipment record for customer named Cathy lee?"
await groupchat.init_selector(q)
# Out:
# -- 1:user -- : Is there any shipment record for customer named Cathy lee?
#
# -- 2:planning_agent -- : 1. schema_agent: Retrieve the database schema information.
# Getting schema
#
# -- 3:schema_agent -- : [FunctionCall(id='call_40l8fAalHRNihJOtL22eZfhU', arguments='{}', name='get_schema_info')]
#
# -- 4:schema_agent -- : [FunctionExecutionResult(content='[\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "customer_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "customers_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "email",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "phone",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "address",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "location_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "locations_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "city",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "state",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "country",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "zip_code",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "product_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "products_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "description",\n    "data_type": "text",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "price",\n    "data_type": "numer ...
#
# -- 5:schema_agent -- : [
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "customers_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "email",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "phone",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "address",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "locations_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "city",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "state",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "country",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "zip_code",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "products_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "description",
#     "data_type": "text",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "price",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "item_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_items_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_product_id_fkey",
#     "referenced_table": "products",
#     "referenced_column": "product_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "quantity",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "tracking_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_tracking_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_location_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "timestamp",
#     "data_type": "timestamp without time zone",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipments_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_date",
#     "data_type": "date",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "origin_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_origin_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "destination_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_destination_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_customer_id_fkey",
#     "referenced_table": "customers",
#     "referenced_column": "customer_id"
#   }
# ]
#
# -- 6:customer_agent -- : [FunctionCall(id='call_5ZFohxYaCLwlEy0MV9rCNmyb', arguments='{"query":"SELECT s.shipment_id, s.status FROM shipments s JOIN customers c ON s.customer_id = c.customer_id WHERE LOWER(c.name) = LOWER(\'Cathy Lee\')"}', name='execute_query')]
#
# -- 7:customer_agent -- : [FunctionExecutionResult(content="[(3, 'In Transit')]", name='execute_query', call_id='call_5ZFohxYaCLwlEy0MV9rCNmyb', is_error=False)]
#
# -- 8:customer_agent -- : [(3, 'In Transit')]
#
# -- 9:shipment_agent -- : [FunctionCall(id='call_GhOFn9MP3S0rdhQO7UIztu03', arguments='{"query":"SELECT s.shipment_id, s.status FROM shipments s JOIN customers c ON s.customer_id = c.customer_id WHERE LOWER(c.name) = \'cathy lee\'"}', name='execute_query')]
#
# -- 10:shipment_agent -- : [FunctionExecutionResult(content="[(3, 'In Transit')]", name='execute_query', call_id='call_GhOFn9MP3S0rdhQO7UIztu03', is_error=False)]
#
# -- 11:shipment_agent -- : [(3, 'In Transit')]
#
# -- 12:user_proxy -- :
# (type 'bye' to exit): bye
# -- 13:user_proxy -- : bye
# Total messages exchanged: 13
# Conversation ended.

# %% [markdown]
# ## Act on your data

# %%
q = "add a new customer with name Jim, email jc@test.ca, phone number +14165551111, address 5 bernard st, new york"
await groupchat.init_magentic(q)
# Out:
# -- 1:user -- : add a new customer with name Jim, email jc@test.ca, phone number +14165551111, address 5 bernard st, new york
#
# -- 2:MagenticOneOrchestrator -- :
# We are working to address the following user request:
#
# add a new customer with name Jim, email jc@test.ca, phone number +14165551111, address 5 bernard st, new york
#
#
# To answer this request we have assembled the following team:
#
# schema_agent: Retrieves database schema information at start of the conversation.
# shipment_agent: Your role is to focus on shipment and products tables.
# customer_agent: Your role is to focus on customer data management.
# user_proxy: Get user input
#
#
# Here is an initial fact sheet to consider:
#
# 1. GIVEN OR VERIFIED FACTS
#    - Name: Jim
#    - Email: jc@test.ca
#    - Phone number: +14165551111
#    - Address: 5 Bernard St, New York
#
# 2. FACTS TO LOOK UP
#    - None specified in request.
#
# 3. FACTS TO DERIVE
#    - None specified in request.
#
# 4. EDUCATED GUESSES
#    - None specified in request.
#
#
# Here is the plan to follow as best as possible:
#
# - **Customer Agent**:
#   - Verify if the customer "Jim" already exists in the database using the provided email or phone number.
#   - If Jim does not exist, proceed to add new customer data to the customers table.
#     - Ensure all provided details (name, email, phone number, address) are correctly entered.
#   - Confirm successful addition of the customer or report any issues encountered during the process.
#
# - **Schema Agent** (if needed):
#   - Confirm the correct schema and fields required for adding a new customer to ensure data compatibility and integrity.
#
# - **User Proxy**:
#   - Collaborate with the user proxy only if there is a need for further clarification or confirmation of customer details.
#
# - **Shipment Agent**:
#   - No action required from the shipment agent as the task specifically involves customer data management, not shipment or products.
#
# This plan focuses on the effective and accurate entry of new customer data utilizing the expertise of the customer agent, with schema verification support from the schema agent if needed, and user interaction through the user proxy only if additional information is required.
#
#
# -- 3:MagenticOneOrchestrator -- : Please verify if a customer named Jim with email jc@test.ca or phone number +14165551111 already exists in the database. If not, proceed to add him.
#
# -- 4:customer_agent -- : Let's first check if customer Jim already exists in the database by using the provided email or phone number.
#
# -- 5:customer_agent -- : [FunctionCall(id='call_wlbZbxJ8K8Lfyc6McEInmF5J', arguments='{"query":"SELECT * FROM customers WHERE email ILIKE \'jc@test.ca\' OR phone_number = \'+14165551111\'"}', name='execute_query')]
#
# -- 6:customer_agent -- : [FunctionExecutionResult(content='[UndefinedColumn(\'column "phone_number" does not exist\\nLINE 1: ... FROM customers WHERE email ILIKE \\\'jc@test.ca\\\' OR phone_numb...\\n                                                             ^\\n\')]', name='execute_query', call_id='call_wlbZbxJ8K8Lfyc6McEInmF5J', is_error=False)]
#
# -- 7:customer_agent -- : [UndefinedColumn('column "phone_number" does not exist\nLINE 1: ... FROM customers WHERE email ILIKE \'jc@test.ca\' OR phone_numb...\n                                                             ^\n')]
#
# -- 8:MagenticOneOrchestrator -- : Please confirm the correct schema and fields related to the phone number in the customers table.
# Getting schema
#
# -- 9:schema_agent -- : [FunctionCall(id='call_QjjFVF7NMiciTRRE8vBX152S', arguments='{}', name='get_schema_info')]
#
# -- 10:schema_agent -- : [FunctionExecutionResult(content='[\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "customer_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "customers_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "email",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "phone",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "address",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "location_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "locations_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "city",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "state",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "country",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "zip_code",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "product_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "products_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "description",\n    "data_type": "text",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "price",\n    "data_type": "nume ...
#
# -- 11:schema_agent -- : [
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "customers_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "email",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "phone",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "address",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "locations_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "city",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "state",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "country",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "zip_code",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "products_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "description",
#     "data_type": "text",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "price",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "item_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_items_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_product_id_fkey",
#     "referenced_table": "products",
#     "referenced_column": "product_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "quantity",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "tracking_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_tracking_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_location_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "timestamp",
#     "data_type": "timestamp without time zone",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipments_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_date",
#     "data_type": "date",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "origin_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_origin_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "destination_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_destination_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_customer_id_fkey",
#     "referenced_table": "customers",
#     "referenced_column": "customer_id"
#   }
# ]
#
# -- 12:MagenticOneOrchestrator -- : Please verify if a customer named Jim with the email jc@test.ca or phone number +14165551111 already exists in the database using the correct column name for the phone field.
#
# -- 13:customer_agent -- : [FunctionCall(id='call_5ZFohxYaCLwlEy0MV9rCNmyb', arguments='{"query":"SELECT * FROM customers WHERE email ILIKE \'jc@test.ca\' OR phone = \'+14165551111\'"}', name='execute_query')]
#
# -- 14:customer_agent -- : [FunctionExecutionResult(content='[]', name='execute_query', call_id='call_5ZFohxYaCLwlEy0MV9rCNmyb', is_error=False)]
#
# -- 15:customer_agent -- : []
#
# -- 16:MagenticOneOrchestrator -- : Please add the new customer named Jim with email jc@test.ca, phone number +14165551111, and address 5 Bernard St, New York to the database.
#
# -- 17:customer_agent -- : [FunctionCall(id='call_5ZFohxYaCLwlEy0MV9rCNmyb', arguments='{"procedure_name":"add_customer","input_vals":["Jim","jc@test.ca","+14165551111","5 Bernard St, New York"]}', name='exec_add_customer')]
#
# -- 18:customer_agent -- : [FunctionExecutionResult(content='Customer added successfully.', name='exec_add_customer', call_id='call_5ZFohxYaCLwlEy0MV9rCNmyb', is_error=False)]
#
# -- 19:customer_agent -- : Customer added successfully.
#
# -- 20:MagenticOneOrchestrator -- : The customer Jim has been successfully added to the database. If there is anything else you need, feel free to let me know!
# Total messages exchanged: 20
# Conversation ended.

# %%
q = "Can you create a new shipment of two laptops to Jim, departing from chicago towards new york?"
await groupchat.init_selector(q)
# Out:
# -- 1:user -- : Can you create a new shipment of two laptops to Jim, departing from chicago towards new york?
#
# -- 2:planning_agent -- : First, I need to retrieve the schema information to understand the database structure. Let's start with that.
#
# 1. schema_agent: Retrieve the database schema information.
# Getting schema
#
# -- 3:schema_agent -- : [FunctionCall(id='call_QjjFVF7NMiciTRRE8vBX152S', arguments='{}', name='get_schema_info')]
#
# -- 4:schema_agent -- : [FunctionExecutionResult(content='[\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "customer_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "customers_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "email",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "phone",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "address",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "location_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "locations_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "city",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "state",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "country",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "zip_code",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "product_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "products_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "description",\n    "data_type": "text",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "price",\n    "data_type": "numer ...
#
# -- 5:schema_agent -- : [
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "customers_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "email",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "phone",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "address",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "locations_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "city",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "state",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "country",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "zip_code",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "products_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "description",
#     "data_type": "text",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "price",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "item_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_items_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_product_id_fkey",
#     "referenced_table": "products",
#     "referenced_column": "product_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "quantity",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "tracking_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_tracking_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_location_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "timestamp",
#     "data_type": "timestamp without time zone",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipments_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_date",
#     "data_type": "date",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "origin_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_origin_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "destination_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_destination_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_customer_id_fkey",
#     "referenced_table": "customers",
#     "referenced_column": "customer_id"
#   }
# ]
#
# -- 6:customer_agent -- : Thank you for providing the database schema information. Now, let's proceed to identify the details required to create the shipment for Jim, including products, locations, and customer information.
#
# First, I need to check if "Jim" is present in the customer database and retrieve his customer ID. Secondly, I will fetch the location IDs for Chicago and New York.
#
# Let's start with querying the customer information for "Jim".
#
# -- 7:customer_agent -- : [FunctionCall(id='call_1gUr7bfvqaapvGxZtyGMmR7o', arguments='{"query":"SELECT customer_id, name FROM customers WHERE lower(name) = \'jim\'"}', name='execute_query')]
#
# -- 8:customer_agent -- : [FunctionExecutionResult(content="[(25, 'Jim')]", name='execute_query', call_id='call_1gUr7bfvqaapvGxZtyGMmR7o', is_error=False)]
#
# -- 9:customer_agent -- : [(25, 'Jim')]
#
# -- 10:shipment_agent -- : Great! Based on the information from "Jim" and the schema mappings:
#
# - Customer ID (name = Jim) = `25`.
#
# Now, I'll check the product ID for laptops and the location IDs for Chicago and New York. Let me find that information next.
#
# -- 11:shipment_agent -- : [FunctionCall(id='call_1gUr7bfvqaapvGxZtyGMmR7o', arguments='{"query":"SELECT product_id, name FROM products WHERE LOWER(name) LIKE \'%laptop%\';"}', name='execute_query')]
#
# -- 12:shipment_agent -- : [FunctionExecutionResult(content="[(1, 'Laptop')]", name='execute_query', call_id='call_1gUr7bfvqaapvGxZtyGMmR7o', is_error=False)]
#
# -- 13:shipment_agent -- : [(1, 'Laptop')]
#
# -- 14:shipment_agent -- : [FunctionCall(id='call_hAEPV9NZm4XnKQR8a5gLkuUA', arguments='{"query":"SELECT location_id, city FROM locations WHERE LOWER(city) = \'chicago\' OR LOWER(city) = \'new york\';"}', name='execute_query')]
#
# -- 15:shipment_agent -- : [FunctionExecutionResult(content="[(1, 'New York'), (3, 'Chicago')]", name='execute_query', call_id='call_hAEPV9NZm4XnKQR8a5gLkuUA', is_error=False)]
#
# -- 16:shipment_agent -- : [(1, 'New York'), (3, 'Chicago')]
#
# -- 17:planning_agent -- : Now that I have all necessary information, let's proceed with the tasks to create the new shipment.
#
# 1. customer_agent: Retrieve customer details for Jim.
# 2. shipment_agent: Verify the availability of two laptops in the inventory.
# 3. shipment_agent: Create a new shipment record from Chicago to New York for customer Jim including adding two laptops to the shipment items.
#
# -- 18:shipment_agent -- : Based on the previously retrieved information, here are the necessary details to create the shipment for Jim:
#
# - **Customer ID:** 25 (Jim)
# - **Product ID for Laptop:** 1
# - **Origin Location ID (Chicago):** 3
# - **Destination Location ID (New York):** 1
#
# I will proceed to create the shipment:
#
# - **Departure date:** Today
# - **Status:** "In transit"
# - **Product list:** [{'product_id': 1, 'quantity': 2}]
#
# Let me handle that now.
#
# -- 19:shipment_agent -- : [FunctionCall(id='call_hAEPV9NZm4XnKQR8a5gLkuUA', arguments='{"procedure_name":"send_shipment","input_vals":[25,3,1,"2023-10-04",[{"product_id":1,"quantity":2}],"in transit","in transit",1]}', name='exec_send_shipment')]
#
# -- 20:shipment_agent -- : [FunctionExecutionResult(content='Shipment sent successfully.', name='exec_send_shipment', call_id='call_hAEPV9NZm4XnKQR8a5gLkuUA', is_error=False)]
#
# -- 21:shipment_agent -- : Shipment sent successfully.
#
# -- 22:user_proxy -- :
# (type 'bye' to exit): bye
# -- 23:user_proxy -- : bye
# Total messages exchanged: 23
# Conversation ended.

# %% [markdown]
# ## Database development

# %%
q = "create a stored procedure in the database that deletes all shipment records for a given shipment id"
await groupchat.init_magentic(q)
# Out:
# -- 1:user -- : create a stored procedure in the database that deletes all shipment records for a given shipment id
#
# -- 2:MagenticOneOrchestrator -- :
# We are working to address the following user request:
#
# create a stored procedure in the database that deletes all shipment records for a given shipment id
#
#
# To answer this request we have assembled the following team:
#
# schema_agent: Retrieves database schema information at start of the conversation.
# shipment_agent: Your role is to focus on shipment and products tables.
# customer_agent: Your role is to focus on customer data management.
# user_proxy: Get user input
#
#
# Here is an initial fact sheet to consider:
#
# 1. GIVEN OR VERIFIED FACTS
#    - The request is to create a stored procedure in a database.
#    - The stored procedure should delete all shipment records for a given shipment id.
#
# 2. FACTS TO LOOK UP
#    - Specific SQL syntax for creating stored procedures, which can be looked up in SQL documentation or database-specific manuals (e.g., Microsoft SQL Server, MySQL, PostgreSQL).
#    - Database schema details including the name and structure of the table that holds shipment records might be found in the database documentation or schema definition files.
#
# 3. FACTS TO DERIVE
#    - There are no explicit facts that need to be derived based on the given request.
#
# 4. EDUCATED GUESSES
#    - The request does not specify which SQL database management system is used, which might influence the specific syntax and capabilities for creating stored procedures.
#    - Handling possible dependencies or using TRANSACTION to ensure data integrity during deletion might be needed based on best practices.
#
#
# Here is the plan to follow as best as possible:
#
# - **schema_agent**:
#   - Retrieve and share the schema details of the shipment table (e.g., table names, relevant column names, and foreign key constraints if any).
#
# - **shipment_agent**:
#   - Use the schema information provided to prepare SQL syntax for the stored procedure which deletes records from the shipment table based on the shipment ID.
#   - Ensure the deletion queries handle possible dependencies or linked records in other tables (like shipment details) using TRANSACTION to maintain data integrity.
#
# - **user_proxy**:
#   - Confirm with the user the database system in use (e.g., MySQL, PostgreSQL, SQL Server) to ensure correct SQL syntax is used.
#   - Verify and confirm the specific requirements and conditions of the stored procedure such as cascading deletions or any specific checks needed before deletion.
#
# - **customer_agent**:
#   - Standby for any possible requirement that may surface related to customer data that could be linked to shipments, although based on the current scope, direct involvement might not be necessary.
#
# This plan keeps the focus on creating the stored procedure with attention to details around data correctness and integrity while being prepared for any additional requirements that might arise related to database specifics or linked data.
#
#
# -- 3:MagenticOneOrchestrator -- : Please provide the schema details for the shipment table, including table name, key columns, and any foreign key constraints related to other tables.
# Getting schema
#
# -- 4:schema_agent -- : [FunctionCall(id='call_QjjFVF7NMiciTRRE8vBX152S', arguments='{}', name='get_schema_info')]
#
# -- 5:schema_agent -- : [FunctionExecutionResult(content='[\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "customer_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "customers_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "email",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "phone",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "address",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "location_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "locations_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "city",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "state",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "country",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "zip_code",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "product_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "products_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "description",\n    "data_type": "text",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "price",\n    "data_type": "numer ...
#
# -- 6:schema_agent -- : [
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "customers_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "email",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "phone",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "address",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "locations_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "city",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "state",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "country",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "zip_code",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "products_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "description",
#     "data_type": "text",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "price",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "item_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_items_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_product_id_fkey",
#     "referenced_table": "products",
#     "referenced_column": "product_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "quantity",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "tracking_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_tracking_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_location_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "timestamp",
#     "data_type": "timestamp without time zone",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipments_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_date",
#     "data_type": "date",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "origin_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_origin_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "destination_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_destination_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_customer_id_fkey",
#     "referenced_table": "customers",
#     "referenced_column": "customer_id"
#   }
# ]
#
# -- 7:MagenticOneOrchestrator -- : Please draft a SQL stored procedure that deletes all records from 'shipments', 'shipment_items', and 'shipment_tracking' tables for a given shipment id, ensuring data integrity with appropriate use of transactions.
#
# -- 8:shipment_agent -- : Based on the schema details you provided and the requirement to maintain data integrity, it would be prudent to use SQL transactions and ensure that deletions in `shipment_items` and `shipment_tracking` are handled before the `shipments` record deletion due to the foreign key constraints. Here's a draft for a PostgreSQL stored procedure:
#
# ```sql
# CREATE OR REPLACE PROCEDURE delete_shipment_records(IN shipment_id_input INTEGER)
# LANGUAGE plpgsql
# AS $$
# BEGIN
#     -- Start a transaction to ensure all or nothing execution
#     BEGIN;
#
#     -- Delete entries from shipment_tracking linked to the shipment_id
#     DELETE FROM shipment_tracking
#     WHERE shipment_id = shipment_id_input;
#
#     -- Delete entries from shipment_items linked to the shipment_id
#     DELETE FROM shipment_items
#     WHERE shipment_id = shipment_id_input;
#
#     -- Finally, delete the shipment entry
#     DELETE FROM shipments
#     WHERE shipment_id = shipment_id_input;
#
#     -- Commit the transaction if all deletions were successful
#     COMMIT;
# EXCEPTION
#     WHEN OTHERS THEN
#         -- Rollback the transaction in case of any error
#         ROLLBACK;
#         RAISE;
# END;
# $$;
# ```
#
# ### Explanation:
# 1. **Transaction Control**: The use of `BEGIN;` and `COMMIT;` ensures that all deletions must succeed together, or if any delete fails, changes will be rolled back to maintain the database's integrity. This is crucial because partial deletions could leave the database in an inconsistent state.
#
# 2. **Error Handling**: The `EXCEPTION` block handles any unexpected errors by rolling back the transaction and re-raising the exception for visibility and further action.
#
# 3. **Procedure Parameters**: The stored procedure accepts one parameter (`shipment_id_input`) which is used to filter the records for deletion based on the `shipment_id`.
#
# This draft ensures that the deletions in the related tables (`shipment_items` and `shipment_tracking`) are handled before attempting to delete the corresponding entry in the primary `shipments` table, respecting the foreign key constraints to avoid integrity errors.
#
# -- 9:MagenticOneOrchestrator -- : Understood! If you need further modifications or have additional database tasks, feel free to ask.
# Total messages exchanged: 9
# Conversation ended.

# %%
await groupchat.close_connection()
# Out:
# Connections pool closed successfully
# You need to create a new instance of the class to use the service again!
