# %%
from pg_utils import init_pool
from multi_agent_chats import GroupChat
import os
# ensure to update .env file with your own values
from dotenv import load_dotenv
load_dotenv(override=True)
pw = os.getenv('POSTGRES_PASSWORD')

# %%
# [OPTIONAL]: uncomment below to run the script setting up the example postgres tables used for this demo
# !python db_init.py

# %% [markdown]
# ## Initialize a connection pool and group chat object

# %%
# Create the connection pool
connection_pool = init_pool(pw)

# %%
groupchat = GroupChat(connection_pool)
# Out:
# Agents and required resources initialized successfully

# %% [markdown]
# ### Example 1: calling a new stored procedure

# %%
q = "can you use delete_shipment_records stored procedure to remove shipment records with shipment_id of 4?"
await groupchat.init_roundrobin(q)
# Out:
# -- 1:user -- : can you use delete_shipment_records stored procedure to remove shipment records with shipment_id of 4?
#
# -- 2:schema_agent -- : I'm here to assist with obtaining schema information and managing stored procedures. I can help with creating and retrieving information about stored procedures, but running specific procedures to manipulate data is not within my capabilities. Let me know if you need help with something else related to stored procedures or schema information!
#
# -- 3:shipment_agent -- : It sounds like you want to delete shipment records using a stored procedure. Before proceeding with this, I recommend reviewing the impact of this deletion to ensure all necessary precautions are taken. Should I go ahead and initiate the deletion process? If yes, please confirm, and I'll handle it for you.
#
# -- 4:customer_agent -- : Before proceeding, I need your confirmation to execute the deletion using the "delete_shipment_records" stored procedure for shipment records with a shipment_id of 4. Please confirm if you'd like me to go ahead with this deletion.
#
# -- 5:user_proxy -- :
# (Type 'bye' to exit): ok
# -- 6:user_proxy -- : ok
#
# -- 7:schema_agent -- : I can help in managing schema or stored procedure information, but I cannot directly execute or manage stored procedures to manipulate data. Please proceed with executing stored procedures in a suitable environment or with the assistance of a relevant tool or agent. If you need help with anything related to stored procedures' structure or schema information, feel free to ask!
# tuple index out of range
#
# -- 8:shipment_agent -- : [FunctionCall(id='call_1gUr7bfvqaapvGxZtyGMmR7o', arguments='{"procedure_name":"delete_shipment_records","input_vals":[4]}', name='exec_send_shipment')]
#
# -- 9:shipment_agent -- : [FunctionExecutionResult(content='An error occurred while executing the stored procedure: tuple index out of range', name='exec_send_shipment', call_id='call_1gUr7bfvqaapvGxZtyGMmR7o', is_error=False)]
#
# -- 10:shipment_agent -- : An error occurred while executing the stored procedure: tuple index out of range
#
# -- 11:customer_agent -- : It appears there was an error indicating a "tuple index out of range" when attempting to execute the deletion. This usually suggests an issue with the input parameters or the way the procedure is defined.
#
# Before proceeding, I'll need to verify the parameters required by the "delete_shipship_records" stored procedure. Could you please provide the schematics or definitions for this stored procedure so I can verify the correct usage? Alternatively, confirm if I should assist in finding out the procedure requirements.
#
# -- 12:user_proxy -- :
# (Type 'bye' to exit): bye
# -- 13:user_proxy -- : bye
# Total messages exchanged: 13
# Conversation ended.

# %%
q = "can you use delete_shipment_records stored procedure to remove shipment records with shipment_id of 4?"
await groupchat.init_selector(q)
# Out:
# -- 1:user -- : can you use delete_shipment_records stored procedure to remove shipment records with shipment_id of 4?
#
# -- 2:planning_agent -- : 1. schema_agent: Please retrieve the database schema information.
# Getting schema
#
# -- 3:schema_agent -- : [FunctionCall(id='call_1gUr7bfvqaapvGxZtyGMmR7o', arguments='{}', name='get_schema_info')]
#
# -- 4:schema_agent -- : [FunctionExecutionResult(content='[\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "customer_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "customers_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "email",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "phone",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "address",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "location_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "locations_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "city",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "state",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "country",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "zip_code",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "product_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "products_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "description",\n    "data_type": "text",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "price",\n    "data_type": "numer ...
#
# -- 5:schema_agent -- : [
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "customers_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "email",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "phone",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "address",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "locations_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "city",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "state",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "country",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "zip_code",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "products_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "description",
#     "data_type": "text",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "price",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "item_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_items_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_product_id_fkey",
#     "referenced_table": "products",
#     "referenced_column": "product_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "quantity",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "tracking_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_tracking_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_location_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "timestamp",
#     "data_type": "timestamp without time zone",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipments_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_date",
#     "data_type": "date",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "origin_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_origin_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "destination_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_destination_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_customer_id_fkey",
#     "referenced_table": "customers",
#     "referenced_column": "customer_id"
#   }
# ]
#
# -- 6:shipment_agent -- : Based on the provided schema information, we can proceed with deleting the shipment record for shipment_id 4 using the "delete_shipment_records" stored procedure.
#
# Would you like me to execute this operation now? Please confirm.
#
# -- 7:user_proxy -- :
# (Type 'bye' to exit): yes
# -- 8:user_proxy -- : yes
#
# -- 9:planning_agent -- : 1. shipment_agent: Please use the "delete_shipment_records" stored procedure to remove the shipment records with shipment_id of 4.
# tuple index out of range
#
# -- 10:shipment_agent -- : [FunctionCall(id='call_d42FS3iWb1x8I4QI0CRD82he', arguments='{"procedure_name":"delete_shipment_records","input_vals":[4]}', name='exec_send_shipment')]
#
# -- 11:shipment_agent -- : [FunctionExecutionResult(content='An error occurred while executing the stored procedure: tuple index out of range', name='exec_send_shipment', call_id='call_d42FS3iWb1x8I4QI0CRD82he', is_error=False)]
#
# -- 12:shipment_agent -- : An error occurred while executing the stored procedure: tuple index out of range
#
# -- 13:user_proxy -- :
# (Type 'bye' to exit): bye
# -- 14:user_proxy -- : bye
# Total messages exchanged: 14
# Conversation ended.

# %%
q = "can you use delete_shipment_records stored procedure to remove shipment records with shipment_id of 4?"
await groupchat.init_magentic(q)
# Out:
# -- 1:user -- : can you use delete_shipment_records stored procedure to remove shipment records with shipment_id of 4?
#
# -- 2:MagenticOneOrchestrator -- :
# We are working to address the following user request:
#
# can you use delete_shipment_records stored procedure to remove shipment records with shipment_id of 4?
#
#
# To answer this request we have assembled the following team:
#
# schema_agent: Retrieves database schema information at start of the conversation. Creates stored procedures.
# shipment_agent: Your role is to focus on shipment and products tables.
# customer_agent: Your role is to focus on customer data management.
# user_proxy: Get user input
#
#
# Here is an initial fact sheet to consider:
#
# 1. GIVEN OR VERIFIED FACTS
#    - The stored procedure is named "delete_shipment_records."
#    - The shipment record to be deleted has a shipment_id of 4.
#
# 2. FACTS TO LOOK UP
#    - The specific database and table where "delete_shipment_records" is implemented need to be verified, potentially in the system’s database documentation or schema definitions.
#    - Verification of the authority or permissions required to execute this stored procedure might be needed, found in system security policies or database management settings.
#
# 3. FACTS TO DERIVE
#    - The impact of removing the shipment record with shipment_id of 4 such as checking any dependencies or related records that might also need modification or deletion.
#
# 4. EDUCATED GUESSES
#    - Assuming the stored procedure "delete_shipment_records" is correctly implemented to handle the removal safely, using it should maintain the integrity of the database.
#
#
# Here is the plan to follow as best as possible:
#
# - **schema_agent**:
#   - Verify if the "delete_shipment_records" stored procedure exists in the database schema.
#   - Confirm the specific database and table associations for the stored procedure.
#
# - **shipment_agent**:
#   - Check logics within "delete_shipment_records" regarding dependency checks, to ensure deleting shipment_id of 4 does not disrupt related tables such as orders or products.
#   - Execute the "delete_shipment_records" stored procedure for shipment_id 4.
#   - Verify the removal by querying the shipment records to confirm that shipment_id 4 no longer exists.
#
# - **customer_agent**:
#   - Confirm if there are any impacts on customer data due to the deletion of shipment_id 4, such as alterations in customer order history or changes in shipping details.
#
# - **user_proxy**:
#   - Obtain necessary authorizations or permissions from the user/admin to execute modification on shipment records if required.
#   - Confirm with the user the completion and outcomes of the deletion process once executed by the shipment_agent.
#
#
# -- 3:MagenticOneOrchestrator -- : Please verify if the 'delete_shipment_records' stored procedure exists and confirm the associated database and table.
# Getting schema
#
# -- 4:schema_agent -- : [FunctionCall(id='call_hAEPV9NZm4XnKQR8a5gLkuUA', arguments='{}', name='get_schema_info')]
#
# -- 5:schema_agent -- : [FunctionExecutionResult(content='[\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "customer_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "customers_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "email",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "phone",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "address",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "location_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "locations_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "city",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "state",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "country",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "zip_code",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "product_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "products_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "description",\n    "data_type": "text",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "price",\n    "data_type": "numer ...
#
# -- 6:schema_agent -- : [
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "customers_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "email",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "phone",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "address",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "locations_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "city",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "state",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "country",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "zip_code",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "products_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "description",
#     "data_type": "text",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "price",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "item_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_items_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_product_id_fkey",
#     "referenced_table": "products",
#     "referenced_column": "product_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "quantity",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "tracking_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_tracking_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_location_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "timestamp",
#     "data_type": "timestamp without time zone",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipments_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_date",
#     "data_type": "date",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "origin_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_origin_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "destination_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_destination_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_customer_id_fkey",
#     "referenced_table": "customers",
#     "referenced_column": "customer_id"
#   }
# ]
#
# -- 7:MagenticOneOrchestrator -- : Please confirm if the 'delete_shipment_records' stored procedure exists in the database and provide any details regarding it, including parameters and associated tables.
#
# -- 8:schema_agent -- : [FunctionCall(id='call_hAEPV9NZm4XnKQR8a5gLkuUA', arguments='{}', name='get_procedure_info')]
#
# -- 9:schema_agent -- : [FunctionExecutionResult(content='[\n  {\n    "routine_schema": "public",\n    "routine_name": "add_customer",\n    "routine_type": "PROCEDURE",\n    "return_type": null,\n    "specific_name": "add_customer_25026"\n  },\n  {\n    "routine_schema": "public",\n    "routine_name": "delete_shipment_records",\n    "routine_type": "PROCEDURE",\n    "return_type": null,\n    "specific_name": "delete_shipment_records_25028"\n  },\n  {\n    "routine_schema": "public",\n    "routine_name": "send_shipment",\n    "routine_type": "PROCEDURE",\n    "return_type": null,\n    "specific_name": "send_shipment_25027"\n  }\n]', name='get_procedure_info', call_id='call_hAEPV9NZm4XnKQR8a5gLkuUA', is_error=False)]
#
# -- 10:schema_agent -- : [
#   {
#     "routine_schema": "public",
#     "routine_name": "add_customer",
#     "routine_type": "PROCEDURE",
#     "return_type": null,
#     "specific_name": "add_customer_25026"
#   },
#   {
#     "routine_schema": "public",
#     "routine_name": "delete_shipment_records",
#     "routine_type": "PROCEDURE",
#     "return_type": null,
#     "specific_name": "delete_shipment_records_25028"
#   },
#   {
#     "routine_schema": "public",
#     "routine_name": "send_shipment",
#     "routine_type": "PROCEDURE",
#     "return_type": null,
#     "specific_name": "send_shipment_25027"
#   }
# ]
#
# -- 11:MagenticOneOrchestrator -- : Please execute the 'delete_shipment_records' stored procedure to remove the shipment record with shipment_id of 4 and confirm whether the execution was successful.
#
# -- 12:shipment_agent -- : [FunctionCall(id='call_xwIL8zdFwYVIibgcScYlhwPf', arguments='{"query":"CALL delete_shipment_records(4)"}', name='execute_query')]
#
# -- 13:shipment_agent -- : [FunctionExecutionResult(content="['Operation successful']", name='execute_query', call_id='call_xwIL8zdFwYVIibgcScYlhwPf', is_error=False)]
#
# -- 14:shipment_agent -- : ['Operation successful']
#
# -- 15:MagenticOneOrchestrator -- : The shipment record with shipment_id of 4 has been successfully removed from the system. If there's anything else I can assist you with, please let me know!
# Total messages exchanged: 15
# Conversation ended.

# %% [markdown]
# ### Example 2: ask a simple question

# %%
q = "How many shipments are there with status of in transit?"
await groupchat.init_magentic(q)
# Out:
# -- 1:user -- : How many shipments are there with status of in transit?
#
# -- 2:MagenticOneOrchestrator -- :
# We are working to address the following user request:
#
# How many shipments are there with status of in transit?
#
#
# To answer this request we have assembled the following team:
#
# schema_agent: Retrieves database schema information at start of the conversation. Creates stored procedures.
# shipment_agent: Your role is to focus on shipment and products tables.
# customer_agent: Your role is to focus on customer data management.
# user_proxy: Get user input
#
#
# Here is an initial fact sheet to consider:
#
# 1. GIVEN OR VERIFIED FACTS
#    - The request asks about the number of shipments with the status of "in transit."
#
# 2. FACTS TO LOOK UP
#    - The specific number of shipments currently listed as "in transit" will need to be looked up, possibly in a logistics database or shipping tracking system where such data is maintained.
#
# 3. FACTS TO DERIVE
#    - There are no facts to derive directly from the given information.
#
# 4. EDUCATED GUESSES
#    - No educated guesses can be made without additional data or context.
#
#
#
# Here is the plan to follow as best as possible:
#
# - **schema_agent**:
#   - Retrieve and confirm the current database schema for the logistics or shipment tracking system to ensure accurate query formulation.
#   - Verify if there is an existing stored procedure that specifically counts shipments based on status, or create one if necessary.
#
# - **shipment_agent**:
#   - Utilize the schema information provided by schema_agent to write and execute an SQL query that counts the number of shipments with the status "in transit" in the shipments table.
#   - Report the retrieved number back to the user.
#
# - **customer_agent**:
#   - Standby for any possible further clarification or additional requests related to customer information that might be related to the shipments.
#
# - **user_proxy**:
#   - Confirm the exact user requirement if any ambiguities arise during the execution of the task.
#   - Present the final counted data of shipments "in transit" to the user and verify if additional information related to these shipments is needed.
#
#
# -- 3:MagenticOneOrchestrator -- : Please confirm the current schema for the shipment tracking database and check if there is an existing stored procedure for counting shipments based on their status.
# Getting schema
#
# -- 4:schema_agent -- : [FunctionCall(id='call_BSEZXFN8Qh4eKTC70KfWZX49', arguments='{}', name='get_schema_info')]
#
# -- 5:schema_agent -- : [FunctionExecutionResult(content='[\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "customer_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "customers_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "email",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "phone",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "address",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "location_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "locations_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "city",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "state",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "country",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "zip_code",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "product_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "products_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "description",\n    "data_type": "text",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "price",\n    "data_type": "numer ...
#
# -- 6:schema_agent -- : [
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "customers_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "email",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "phone",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "address",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "locations_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "city",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "state",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "country",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "zip_code",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "products_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "description",
#     "data_type": "text",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "price",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "item_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_items_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_product_id_fkey",
#     "referenced_table": "products",
#     "referenced_column": "product_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "quantity",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "tracking_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_tracking_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_location_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "timestamp",
#     "data_type": "timestamp without time zone",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipments_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_date",
#     "data_type": "date",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "origin_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_origin_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "destination_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_destination_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_customer_id_fkey",
#     "referenced_table": "customers",
#     "referenced_column": "customer_id"
#   }
# ]
#
# -- 7:MagenticOneOrchestrator -- : Please write and execute an SQL query to count the number of shipments that are currently 'in transit' as per the 'shipments' or 'shipment_tracking' tables.
#
# -- 8:shipment_agent -- : [FunctionCall(id='call_hAEPV9NZm4XnKQR8a5gLkuUA', arguments='{"query":"SELECT COUNT(*) FROM shipments WHERE LOWER(status) = \'in transit\'"}', name='execute_query')]
#
# -- 9:shipment_agent -- : [FunctionExecutionResult(content='[(7,)]', name='execute_query', call_id='call_hAEPV9NZm4XnKQR8a5gLkuUA', is_error=False)]
#
# -- 10:shipment_agent -- : [(7,)]
#
# -- 11:MagenticOneOrchestrator -- : The total number of shipments currently listed as "in transit" is 7.
#
# Would you like any additional information related to these shipments?
# Total messages exchanged: 11
# Conversation ended.

# %%
q = "How many shipments are there with status of in transit?"
await groupchat.init_selector(q)
# Out:
# -- 1:user -- : How many shipments are there with status of in transit?
#
# -- 2:planning_agent -- : 1. schema_agent: Retrieve the database schema information.
# Getting schema
#
# -- 3:schema_agent -- : [FunctionCall(id='call_dJsiHyoQy8BwNCidPSbvC9UX', arguments='{}', name='get_schema_info')]
#
# -- 4:schema_agent -- : [FunctionExecutionResult(content='[\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "customer_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "customers_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "email",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "phone",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "address",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "location_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "locations_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "city",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "state",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "country",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "zip_code",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "product_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "products_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "description",\n    "data_type": "text",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "price",\n    "data_type": "numer ...
#
# -- 5:schema_agent -- : [
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "customers_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "email",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "phone",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "address",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "locations_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "city",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "state",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "country",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "zip_code",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "products_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "description",
#     "data_type": "text",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "price",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "item_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_items_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_product_id_fkey",
#     "referenced_table": "products",
#     "referenced_column": "product_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "quantity",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "tracking_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_tracking_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_location_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "timestamp",
#     "data_type": "timestamp without time zone",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipments_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_date",
#     "data_type": "date",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "origin_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_origin_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "destination_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_destination_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_customer_id_fkey",
#     "referenced_table": "customers",
#     "referenced_column": "customer_id"
#   }
# ]
#
# -- 6:shipment_agent -- : [FunctionCall(id='call_hAEPV9NZm4XnKQR8a5gLkuUA', arguments='{"query":"SELECT COUNT(*) FROM shipments WHERE LOWER(status) = \'in transit\'"}', name='execute_query')]
#
# -- 7:shipment_agent -- : [FunctionExecutionResult(content='[(7,)]', name='execute_query', call_id='call_hAEPV9NZm4XnKQR8a5gLkuUA', is_error=False)]
#
# -- 8:shipment_agent -- : [(7,)]
#
# -- 9:user_proxy -- :
# (Type 'bye' to exit): bye
# -- 10:user_proxy -- : bye
# Total messages exchanged: 10
# Conversation ended.

# %%
q = "How many shipments are there with status of in transit?"
await groupchat.init_roundrobin(q)
# Out:
# -- 1:user -- : How many shipments are there with status of in transit?
# Getting schema
#
# -- 2:schema_agent -- : Before proceeding, I need to first acquire the schema information of the database to understand the structure of tables and available fields.
#
# Let me fetch that information for you.
#
# -- 3:schema_agent -- : [FunctionCall(id='call_BSEZXFN8Qh4eKTC70KfWZX49', arguments='{}', name='get_schema_info')]
#
# -- 4:schema_agent -- : [FunctionExecutionResult(content='[\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "customer_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "customers_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "email",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "phone",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "customers",\n    "column_name": "address",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "location_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "locations_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "city",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "state",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "country",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "locations",\n    "column_name": "zip_code",\n    "data_type": "character varying",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "product_id",\n    "data_type": "integer",\n    "is_nullable": "NO",\n    "constraint_type": "PRIMARY KEY",\n    "constraint_name": "products_pkey",\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "name",\n    "data_type": "character varying",\n    "is_nullable": "NO",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "description",\n    "data_type": "text",\n    "is_nullable": "YES",\n    "constraint_type": null,\n    "constraint_name": null,\n    "referenced_table": null,\n    "referenced_column": null\n  },\n  {\n    "table_schema": "public",\n    "table_name": "products",\n    "column_name": "price",\n    "data_type": "numer ...
#
# -- 5:schema_agent -- : [
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "customers_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "email",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "phone",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "customers",
#     "column_name": "address",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "locations_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "city",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "state",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "country",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "locations",
#     "column_name": "zip_code",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "products_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "name",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "description",
#     "data_type": "text",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "price",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "products",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "item_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_items_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "product_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_items_product_id_fkey",
#     "referenced_table": "products",
#     "referenced_column": "product_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "quantity",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_items",
#     "column_name": "weight",
#     "data_type": "numeric",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "tracking_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipment_tracking_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_shipment_id_fkey",
#     "referenced_table": "shipments",
#     "referenced_column": "shipment_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "location_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipment_tracking_location_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipment_tracking",
#     "column_name": "timestamp",
#     "data_type": "timestamp without time zone",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_id",
#     "data_type": "integer",
#     "is_nullable": "NO",
#     "constraint_type": "PRIMARY KEY",
#     "constraint_name": "shipments_pkey",
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "shipment_date",
#     "data_type": "date",
#     "is_nullable": "NO",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "status",
#     "data_type": "character varying",
#     "is_nullable": "YES",
#     "constraint_type": null,
#     "constraint_name": null,
#     "referenced_table": null,
#     "referenced_column": null
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "origin_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_origin_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "destination_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_destination_id_fkey",
#     "referenced_table": "locations",
#     "referenced_column": "location_id"
#   },
#   {
#     "table_schema": "public",
#     "table_name": "shipments",
#     "column_name": "customer_id",
#     "data_type": "integer",
#     "is_nullable": "YES",
#     "constraint_type": "FOREIGN KEY",
#     "constraint_name": "shipments_customer_id_fkey",
#     "referenced_table": "customers",
#     "referenced_column": "customer_id"
#   }
# ]
#
# -- 6:shipment_agent -- : [FunctionCall(id='call_hAEPV9NZm4XnKQR8a5gLkuUA', arguments='{"query":"SELECT COUNT(*) FROM shipments WHERE LOWER(status) = \'in transit\'"}', name='execute_query')]
#
# -- 7:shipment_agent -- : [FunctionExecutionResult(content='[(7,)]', name='execute_query', call_id='call_hAEPV9NZm4XnKQR8a5gLkuUA', is_error=False)]
#
# -- 8:shipment_agent -- : [(7,)]
#
# -- 9:customer_agent -- : The number of shipments that are currently "In Transit" is 7.
#
# -- 10:user_proxy -- :
# (Type 'bye' to exit): bye
# -- 11:user_proxy -- : bye
# Total messages exchanged: 11
# Conversation ended.

# %% [markdown]
# ### close database connection pool when done

# %%
await groupchat.close_connection()
# Out:
# Connections pool closed successfully
# You need to create a new instance of the class to use the service again!
